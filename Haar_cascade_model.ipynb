# %% [markdown]
# <a href="https://colab.research.google.com/github/silvererudite/ML_algos_onSomeDatasets/blob/master/Haar_cascade_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('/content/lady.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7FAEFAE1F550>

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=509x339 at 0x7FAEFAE1F150>

# %%
haar_cascade = cv.CascadeClassifier('/content/haar_face.xml')

faces_rect = haar_cascade.detectMultiScale(gray, scaleFactor = 1.1, minNeighbors = 3)

print(f'Number of faces found = {len(faces_rect)}')
# Out:
# Number of faces found = 2

# %%
for (x,y,w,h) in faces_rect:
  cv.rectangle(img, (x,y), (x+w,y+h),(0,255,0), thickness=2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=509x339 at 0x7FAEFAE874D0>
